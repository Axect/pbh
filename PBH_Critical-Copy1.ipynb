# %% [markdown]
# <div style="text-align:center"><h1>RGEs of PBH</h1></div>
# <div style="text-align:right"><b>Tae Geun Kim</b></div>
# ******
# $$\xi = 1500$$

# %% [markdown]
# ## 1. For $\lambda$
# *****
# ### 1) Import Data
# * Using Mathematica, generate table (name="lHTab.csv")
# * If you want to see a full code, then click below.

# %%
from IPython.display import HTML

HTML('''<script>
code_show=true; 
function code_toggle() {
 if (code_show){
 $('div.input').hide();
 } else {
 $('div.input').show();
 }
 code_show = !code_show
} 
$( document ).ready(code_toggle);
</script>
<form action="javascript:code_toggle()"><input type="submit" value="Click here to toggle on/off the raw code."></form>''')
# Out:
# <script>
# code_show=true;
# function code_toggle() {
#  if (code_show){
#  $('div.input').hide();
#  } else {
#  $('div.input').show();
#  }
#  code_show = !code_show
# }
# $( document ).ready(code_toggle);
# </script>
# <form action="javascript:code_toggle()"><input type="submit" value="Click here to toggle on/off the raw code."></form>

# %%
#%%bash
#sed -ie 's/{/[/g' /home/rakhan/lHTab.csv
#sed -ie 's/}/]/g' /home/rakhan/lHTab.csv
#sed -ie 's/{/[/g' /home/rakhan/lHTabl.csv
#sed -ie 's/}/]/g' /home/rakhan/lHTabl.csv
#sed -ie 's/{/[/g' /home/rakhan/LHTab.csv
#sed -ie 's/}/]/g' /home/rakhan/LHTab.csv
#sed -ie 's/{/[/g' /home/rakhan/lHdTab.csv
#sed -ie 's/}/]/g' /home/rakhan/lHdTab.csv
#sed -ie 's/{/[/g' /home/rakhan/lHdTabl.csv
#sed -ie 's/}/]/g' /home/rakhan/lHdTabl.csv
#sed -ie 's/{/[/g' /home/rakhan/LHdTab.csv
#sed -ie 's/}/]/g' /home/rakhan/LHdTab.csv
#sed -ie 's/{/[/g' /home/rakhan/PoTab.csv
#sed -ie 's/}/]/g' /home/rakhan/PoTab.csv
#sed -ie 's/{/[/g' /home/rakhan/POTab.csv
#sed -ie 's/}/]/g' /home/rakhan/POTab.csv

# %%
#%%bash
#mkdir /home/rakhan/PBH_data2

# %%
#%%bash
#mv /home/rakhan/lHTab.csv /home/rakhan/PBH_data2/lHTab.csv
#mv /home/rakhan/lHTabl.csv /home/rakhan/PBH_data2/lHTabl.csv
#mv /home/rakhan/LHTab.csv /home/rakhan/PBH_data/LHTab.csv
#mv /home/rakhan/lHdTab.csv /home/rakhan/PBH_data/lHdTab.csv
#mv /home/rakhan/lHdTabl.csv /home/rakhan/PBH_data/lHdTabl.csv
#mv /home/rakhan/LHdTab.csv /home/rakhan/PBH_data/LHdTab.csv
#mv /home/rakhan/PoTab.csv /home/rakhan/PBH_data/PoTab.csv
#mv /home/rakhan/POTab.csv /home/rakhan/PBH_data/POTab.csv

# %%
# Text to List
import ast
from math import exp, sqrt

MpR = 2.435*10**(18)
# Import & Edit data automatically.
temp = open('/home/rakhan/PBH_data2/lHTab.csv')
Data = [line.strip().strip('"') for line in temp]
for i, mass_group in enumerate(Data):
    Data[i] = ast.literal_eval(mass_group)

# Extract t, $\lambda$
for i in range(165,176):
    locals()['t_'+str(i)] = []
    locals()['te_'+str(i)] = []
    locals()['lambda_'+str(i)] = []
for i, mass_group in enumerate(Data):
    for values in mass_group:
        locals()['t_'+str(i+165)].append(values[0])
        locals()['te_'+str(i+165)].append(exp(values[0])*(i+165)/MpR)
        locals()['lambda_'+str(i+165)].append(values[2])

# %% [markdown]
# ### 2) Plot $\lambda$
# *****
# #### - Simple Plot

# %%
# Matplotlib
import matplotlib.pyplot as plt

# Use latex
plt.rc('text', usetex=True)
plt.rc('font', family='serif')
null=[0 for i in t_165]
plt.figure(figsize=(10,6))
for i in range(165, 176):
    plt.plot(locals()['t_'+str(i)],locals()['lambda_'+str(i)],label=r"$m_t="+str(i)+"$")
plt.plot(t_165, null, color='black')
plt.legend()
plt.xlabel(r'$t=\log(\mu/M_t)$', fontsize=14)
plt.ylabel(r'$\lambda$', fontsize=14)
plt.grid()
plt.show()

# %% [markdown]
# #### - Is it Normalized?

# %%
null=[0 for i in t_165]
plt.figure(figsize=(10,6))
for i in range(165, 176):
    plt.plot(locals()['te_'+str(i)],locals()['lambda_'+str(i)],label=r"$m_t="+str(i)+"$")
plt.plot(t_165, null, color='black')
plt.legend()
plt.xlabel(r'$\phi$ (in units of $M_p$)', fontsize=14)
plt.ylabel(r'$\lambda$', fontsize=14)
plt.grid()
plt.show()

# %% [markdown]
# #### - Idea : Flat parts of $\displaystyle\frac{\lambda}{\xi^2} \sim 10^{-10}$

# %% [markdown]
# #### - Beautiful Plot (Optional)

# %%
#import plotly.plotly as py
#import plotly.graph_objs as go
#from plotly.tools import FigureFactory as FF

# %%
#for i in range(165,176):
#    locals()['trace'+str(i-165)] = go.Scatter(
#        x = t_165,
#        y = locals()['lambda_'+str(i)],
#        mode = 'lines',
#        name = '$M_t='+str(i)+'$'
#    )
#data = [trace0, trace1, trace2, trace3, trace4, trace5, trace6, trace7, trace8, trace9, trace10]
#layout = go.Layout(
#    xaxis=dict(
#        title='$\\log(\\mu/M_t)$',
#    ),
#    yaxis=dict(
#        title='$\\lambda$',
#    )
#)
#fig = go.Figure(data=data, layout=layout)
#py.iplot(fig, filename='PBH_lambda')

# %% [markdown]
# #### - Conclusion
# * Thus, we can find if $M_t > 171GeV$, then $\lambda$ should be negative
# * Then let's check $M_t \simeq 171GeV$.

# %% [markdown]
# ### 3) More Specific ($170 \sim 171GeV$)
# *****
# #### - Import Data from Mathematica

# %%
# Import & Edit data automatically.
temp2 = open('/home/rakhan/PBH_data/lHTabl.csv')
Data2 = [line.strip().strip('"') for line in temp2]
for i, mass_group in enumerate(Data2):
    Data2[i] = ast.literal_eval(mass_group)

# Extract t, $\lambda$
for i in range(101):
    locals()['t2_'+str(i)] = []
    locals()['lambda2_'+str(i)] = []
for i, mass_group in enumerate(Data2):
    for values in mass_group:
        locals()['t2_'+str(i)].append(values[0])
        locals()['lambda2_'+str(i)].append(values[2])

# %% [markdown]
# ####  - Plot

# %%
# See 170.81 - 170.89
NULL = [0 for i in range(0,4001)]
plt.figure(figsize=(10,6))
for i in range(101):
    if 80<i<90:
        plt.plot(locals()['t2_'+str(i)][3200:3700],locals()['lambda2_'+str(i)][3200:3700],label=r"$m_t=170."+str(i)+"$")
plt.plot(t2_0[3200:3700],NULL[3200:3700],color='black')
plt.xlabel(r'$t=\log(\mu/M_t)$', fontsize=14)
plt.ylabel(r'$\lambda$', fontsize=14)
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# #### - Conclusion
# * We can find $M_t \in (170.85, 170.86)$
# > Thus, let's find $33\leq t\leq 37,\,170.85\leq M_t \leq 170.86$

# %% [markdown]
# ### 4) More Precise ($33\leq t\leq 37,\,170.85\leq M_t \leq 170.86$)
# *****
# #### - Import Data from Mathematica

# %%
# Import & Edit data automatically.
temp3 = open('/home/rakhan/PBH_data/LHTab.csv')
Data3 = [line.strip().strip('"') for line in temp3]
for i, mass_group in enumerate(Data3):
    Data3[i] = ast.literal_eval(mass_group)

# Extract t, $\lambda$
for i in range(40001):
    locals()['t3_'+str(i)] = []
    locals()['lambda3_'+str(i)] = []
for i, mass_group in enumerate(Data3):
    for values in mass_group:
        locals()['t3_'+str(i)].append(values[0])
        locals()['lambda3_'+str(i)].append(values[2])

# %% [markdown]
# #### - Find minimum $|\lambda|<10^{-6}$

# %%
# %load_ext Cython

# %%
# %%cython
#
# def Find_min(List, float h, int num):
#     cdef int i
#     if abs(min(List)) < h:
#         return num
#     else:
#         pass

# %%
keys = []
for i in range(101):
    a = Find_min(locals()['lambda3_'+str(i)], 0.000001, i)
    if a is not None:
        keys.append(a)
print(keys)
# Out:
# [51, 52, 53, 54]

# %% [markdown]
# * The reult saids $M_t = 170.8551, 170.8552, 170.8553, 170.8554$

# %% [markdown]
# #### - Plot

# %%
NULL2 = [0 for i in t3_0]
plt.figure(figsize=(10,6))
for i in keys:
    plt.plot(locals()['t3_'+str(i)][20000:25000],locals()['lambda3_'+str(i)][20000:25000],label=r"$m_t=170.85"+str(i)+"$")
plt.plot(t3_0[20000:25000],NULL2[20000:25000],color='black')
plt.xlabel(r'$t=\log(\mu/M_t)$', fontsize=14)
plt.ylabel(r'$\lambda$', fontsize=14)
plt.legend()
plt.grid()
plt.show()

# %%
from math import log10, exp

# %%
# The minimum Value
print('Minimum of 170.8552: ', min(lambda3_52))
print('Minimum of 170.8553: ',min(lambda3_53))

# Where is the minimum?
for i in range(len(lambda3_52)-1):
    if lambda3_52[i] < lambda3_52[i+1]:
        print('170.8552: t=' ,33+0.0001*i,' log10(t)=', log10(exp(33+0.0001*i)))
        break
for i in range(len(lambda3_53)-1):
    if lambda3_53[i] < lambda3_53[i+1]:
        print('170.8553: t=' ,33+0.0001*i,' log10(t)=',log10(exp(33+0.0001*i)))
        break
# Out:
# Minimum of 170.8552:  3.147261869e-07
# Minimum of 170.8553:  -3.234661085e-07
# 170.8552: t= 35.313  log10(t)= 15.336241039449533
# 170.8553: t= 35.313  log10(t)= 15.336241039449533

# %% [markdown]
# ####  - Conclusion
# * $170.8552 \leq M_t \leq 170.8553$
# * $M_t = 170.8552 \rightarrow t=35.313:\, \lambda=3.147261869\times10^{-7}$
# * $M_t = 170.8553 \rightarrow t=35.313:\, \lambda=-3.234661085\times10^{-7}$

# %% [markdown]
# ## 2. For $\displaystyle \frac{d\lambda}{d\ln\mu}$
# *******
# ### 1) Overview
# #### - Import Data from Mathematica

# %%
# Import & Edit data automatically.
tempb = open('/home/rakhan/PBH_data/lHdTab.csv')
Datab = [line.strip().strip('"') for line in tempb]
for i, mass_group in enumerate(Datab):
    Datab[i] = ast.literal_eval(mass_group)
    
# Extract t, $\lambda$
for i in range(len(Datab)):
    locals()['tb_'+str(i)] = []
    locals()['lambdab_'+str(i)] = []
for i, mass_group in enumerate(Datab):
    for values in mass_group:
        locals()['tb_'+str(i)].append(values[0])
        locals()['lambdab_'+str(i)].append(values[2])

# %% [markdown]
# ####  - Plot

# %%
null=[0 for i in tb_0]
plt.figure(figsize=(10,6))
for i in range(len(Datab)):
    plt.plot(locals()['tb_'+str(i)],locals()['lambdab_'+str(i)],label=r"$m_t="+str(i+165)+"$")
plt.plot(tb_0, null, color='black')
plt.legend()
plt.xlabel(r'$t=\ln(\mu/M_t)$', fontsize=14)
plt.ylabel(r'$\displaystyle \frac{d\lambda}{d\ln\mu}$', fontsize=14)
plt.grid()
plt.show()

# %% [markdown]
# #### - Numpy

# %%
import numpy as np

# %%
tstep = t_165[2] - t_165[1]
for i in range(len(Data)):
    locals()['tb0_'+str(i)] = [element + 0.5 * tstep for element in locals()['t_'+str(i+165)]]
    locals()['lambdab0_'+str(i)] = []
for i in range(len(Data)):
    del(locals()['tb0_'+str(i)][-1])
    locals()['lambdab0_'+str(i)] = np.diff(locals()['lambda_'+str(i+165)]) / np.diff(locals()['t_'+str(i+165)])

# %%
null0=[0 for i in tb0_0]
plt.figure(figsize=(10,6))
for i in range(len(Datab)):
    plt.plot(locals()['tb0_'+str(i)],locals()['lambdab0_'+str(i)],label=r"$m_t="+str(i+165)+"$")
plt.plot(tb0_0, null0, color='black')
plt.legend()
plt.xlabel(r'$t=\ln(\mu/M_t)$', fontsize=14)
plt.ylabel(r'$\displaystyle \frac{d\lambda}{d\ln\mu}$', fontsize=14)
plt.grid()
plt.show()

# %% [markdown]
# ### 2) More Specific ($170GeV\leq M_t\leq 171GeV$)

# %% [markdown]
# ####  - Import Data from Mathematica

# %%
# Import & Edit data automatically.
tempb2 = open('/home/rakhan/PBH_data/lHdTabl.csv')
Datab2 = [line.strip().strip('"') for line in tempb2]
for i, mass_group in enumerate(Datab2):
    Datab2[i] = ast.literal_eval(mass_group)

# Extract t, $\lambda$
for i in range(101):
    locals()['tb2_'+str(i)] = []
    locals()['lambdab2_'+str(i)] = []
for i, mass_group in enumerate(Datab2):
    for values in mass_group:
        locals()['tb2_'+str(i)].append(values[0])
        locals()['lambdab2_'+str(i)].append(values[2])

# %% [markdown]
# #### - Plot

# %%
# See 170.81 - 170.89
NULLb = [0 for i in range(0,4001)]
plt.figure(figsize=(10,6))
for i in range(101):
    if 80<i<90:
        plt.plot(locals()['tb2_'+str(i)][3531:3533],locals()['lambdab2_'+str(i)][3531:3533],label=r"$m_t=170."+str(i)+"$")
plt.plot(tb2_0[3531:3533],NULLb[3531:3533],color='black')
plt.plot(35.313,0,'.',color='red',label='Critical')
plt.xlabel(r'$t=\log(\mu/M_t)$', fontsize=14)
plt.ylabel(r'$\displaystyle \frac{d\lambda}{d\ln\mu}$', fontsize=14)
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# ####  - Numpy

# %%
tstep2 = t2_0[1] - t2_0[0]
for i in range(101):
    locals()['tb02_'+str(i)] = [element + 0.5 * tstep2 for element in locals()['t2_'+str(i)]]
    locals()['lambdab02_'+str(i)] = []
for i, _ in enumerate(Data2):
    del( locals()['tb02_'+str(i)][-1])
    locals()['lambdab02_'+str(i)] = np.diff(locals()['lambda2_'+str(i)]) / np.diff(locals()['t2_'+str(i)])

# %%
# See 170.81 - 170.89
NULL02 = [0 for i in range(0,4001)]
plt.figure(figsize=(10,6))
for i in range(101):
    if 80<i<90:
        plt.plot(locals()['tb02_'+str(i)][3530:3532],locals()['lambdab02_'+str(i)][3530:3532],label=r"$m_t=170."+str(i)+"$")
plt.plot(tb02_0[3530:3532],NULL02[3530:3532],color='black')
plt.plot(35.313,0,'.',color='red',label='Critical')
plt.xlabel(r'$t=\log(\mu/M_t)$', fontsize=14)
plt.ylabel(r'$\displaystyle \frac{d\lambda}{d\ln\mu}$', fontsize=14)
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# ### 3) More Precise ($t\simeq 35.313,\, M_t\simeq170.8552GeV$)

# %% [markdown]
# #### - Import Data from Mathematica

# %%
# Import & Edit data automatically.
tempb3 = open('/home/rakhan/PBH_data/LHdTab.csv')
Datab3 = [line.strip().strip('"') for line in tempb3]
for i, mass_group in enumerate(Datab3):
    Datab3[i] = ast.literal_eval(mass_group)

# Extract t, $\lambda$
for i in range(40001):
    locals()['tb3_'+str(i)] = []
    locals()['lambdab3_'+str(i)] = []
for i, mass_group in enumerate(Datab3):
    for values in mass_group:
        locals()['tb3_'+str(i)].append(values[0])
        locals()['lambdab3_'+str(i)].append(values[2])

# %% [markdown]
# #### - Plot ($35.3129\leq t \leq 35.3131$)

# %%
NULLb2 = [0 for i in tb3_0]
plt.figure(figsize=(10,6))
for i in keys:
    plt.plot(locals()['tb3_'+str(i)][23129:23132],locals()['lambdab3_'+str(i)][23129:23132],label=r"$m_t=170.85"+str(i)+"$")
    plt.plot(locals()['tb3_'+str(i)][23129:23132],locals()['lambdab3_'+str(i)][23129:23132],'o')
plt.plot(tb3_0[23129:23132],NULLb2[23129:23132],color='black')
plt.plot(35.313,0,'>',color='blue',label='Critical')
plt.xlabel(r'$t=\log(\mu/M_t)$', fontsize=14)
plt.ylabel(r'$\frac{d\lambda}{d\ln\mu}$', fontsize=14)
plt.legend()
plt.grid()
plt.show()

# %%
# The minimum Value
print('Minimum of 170.8552: ', min(lambdab3_52))
print('Minimum of 170.8553: ',min(lambdab3_53))

# Where is the minimum?
for i in range(len(lambdab3_52)-1):
    if abs(lambdab3_52[i]) < abs(lambdab3_52[i+1]):
        print('170.8552: t=' ,33+0.0001*i,' log10(t)=', log10(exp(33+0.0001*i)))
        break
for i in range(len(lambdab3_53)-1):
    if abs(lambdab3_53[i]) < abs(lambdab3_53[i+1]):
        print('170.8553: t=' ,33+0.0001*i,' log10(t)=',log10(exp(33+0.0001*i)))
        break
# Out:
# Minimum of 170.8552:  -0.0001211399332454
# Minimum of 170.8553:  -0.0001211405050003
# 170.8552: t= 35.313  log10(t)= 15.336241039449533
# 170.8553: t= 35.313  log10(t)= 15.336241039449533

# %% [markdown]
# ## 3. Results

# %% [markdown]
# * $170.8552 \leq M_t \leq 170.8553$
# * $M_t = 170.8552 \rightarrow t=35.313:\, \lambda=3.147261869\times10^{-7}$
# * $M_t = 170.8553 \rightarrow t=35.313:\, \lambda=-3.234661085\times10^{-7}$

# %% [markdown]
# ## 4. Potential
# ******
# ### 1) Overview
# #### - Import Data from Mathematica

# %%
# Import & Edit data automatically.
tempp = open('/home/rakhan/PBH_data/PoTab.csv')
Datap = [line.strip().strip('"') for line in tempp]
for i, mass_group in enumerate(Datap):
    Datap[i] = ast.literal_eval(mass_group)

# Extract t, $\lambda$
for i in range(len(Datap)):
    locals()['h_'+str(i)] = []
    locals()['VE_'+str(i)] = []
for i, mass_group in enumerate(Datap):
    for values in mass_group:
        locals()['h_'+str(i)].append(values[2])
        locals()['VE_'+str(i)].append(values[3])

# %% [markdown]
# #### - Plot

# %%
NULLp = [0 for i in h_0]
plt.figure(figsize=(10,6))
for i in range(len(Datap)):
    plt.plot(locals()['h_'+str(i)],locals()['VE_'+str(i)],label=r"$m_t="+str(i+165)+"$")
#plt.plot(tp_0,NULLp,color='black')
plt.xlabel(r'Field Value (in units of $M_p$)', fontsize=14)
plt.ylabel(r'$V_E$ (in units of $M_p^4$)', fontsize=14)
plt.legend()
plt.grid()
plt.show()

# %%
NULLp = [0 for i in h_0]
plt.figure(figsize=(10,6))
for i in range(len(Datap)):
    plt.plot(locals()['h_'+str(i)],locals()['VE_'+str(i)],label=r"$m_t="+str(i+165)+"$")
#plt.plot(tp_0,NULLp,color='black')
plt.xlabel(r'Field Value (in units of $M_p$)', fontsize=14)
plt.ylabel(r'$V_E$ (in units of $M_p^4$)', fontsize=14)
plt.legend()
plt.axis([0, 1, 0, 0.0000001])
plt.grid()
plt.show()

# %% [markdown]
# #### - Plot ($M_t = 170,171GeV$)

# %%
plt.figure(figsize=(10,6))
plt.plot(h_5,VE_5,label=r"$M_t=170$",color='red')
plt.plot(h_6,VE_6,label=r"$M_t=171$",color='blue')
#plt.plot(h_6,VE_6,'.',label=r"$M_t=171$",color='blue')
plt.xlabel(r'Field Value (in units of $M_p$)', fontsize=14)
plt.ylabel(r'$V_E$ (in units of $M_p^4$)', fontsize=14)
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# ### 2) More Specific ($170.844GeV\leq M_t \leq 170.856GeV$)
# #### - Import Data from Mathematica

# %%
# Import & Edit data automatically.
temp_pot = open('/home/rakhan/PBH_data/Potential.csv')
Data_pot = [line.strip().strip('"') for line in temp_pot]
for i, mass_group in enumerate(Data_pot):
    Data_pot[i] = ast.literal_eval(mass_group)

# Extract t, $\lambda$
for i in range(len(Data_pot)):
    locals()['hpot_'+str(i)] = []
    locals()['VEpot_'+str(i)] = []
for i, mass_group in enumerate(Data_pot):
    for values in mass_group:
        locals()['hpot_'+str(i)].append(values[2])
        locals()['VEpot_'+str(i)].append(values[3])

# %% [markdown]
# #### - Plot

# %%
plt.figure(figsize=(10,6))
for i,_ in enumerate(Data_pot):
    if i < 6:
        plt.plot(locals()['hpot_'+str(i)],locals()['VEpot_'+str(i)],label=r'$M_t=170.84'+str(i+4)+'$')
    else:
        plt.plot(locals()['hpot_'+str(i)],locals()['VEpot_'+str(i)],label=r'$M_t=170.85'+str(i-6)+'$')
plt.xlabel(r'Field Value (in units of $M_p$)', fontsize=14)
plt.ylabel(r'$V_E$ (in units of $M_p^4$)', fontsize=14)
plt.legend()
plt.grid()
plt.show()

# %%
plt.figure(figsize=(10,6))
for i,_ in enumerate(Data_pot):
    if 3 < i < 6:
        plt.plot(locals()['hpot_'+str(i)],locals()['VEpot_'+str(i)],label=r'$M_t=170.84'+str(i+4)+'$')
    elif i >= 6:
        plt.plot(locals()['hpot_'+str(i)],locals()['VEpot_'+str(i)],label=r'$M_t=170.85'+str(i - 6)+'$')
# i = 6 -> 170.849
plt.xlabel(r'Field Value (in units of $M_p$)', fontsize=14)
plt.ylabel(r'$V_E$ (in units of $M_p^4$)', fontsize=14)
plt.legend()
plt.axis([0, 1.5, 0, 0.000000004])
plt.grid()
plt.show()

# %% [markdown]
# ### 3) See Inflection Point ($M_t = 170.849GeV$)
# #### - Derivative

# %%
hdpot_5 = [(hpot_5[i] + hpot_5[i+1])/2 for i in range(len(hpot_5)-1)]
VEdpot_5 = np.diff(VEpot_5)/np.diff(hpot_5)
plt.figure(figsize=(10,6))
plt.plot(hdpot_5,VEdpot_5,label=r'$M_t=170.849$')
plt.xlabel(r'Field Value (in units of $M_p$)', fontsize=14)
plt.ylabel(r'$\displaystyle \frac{dV_E}{dh}$ (in units of $M_p^3$)', fontsize=14)
plt.legend()
plt.axis([0, 1.5, 0, 0.00000002])
plt.grid()
plt.show()

# %%
for i, elem in enumerate(hdpot_5):
    if VEdpot_5[i] == min(VEdpot_5[298:]):
        print('h =',elem,": V'=0")
        inflec = elem
# Out:
# h = 0.35119 : V'=0

# %% [markdown]
# #### - Inflection Point

# %%
hddpot_5 = [(hdpot_5[i] + hdpot_5[i+1])/2 for i in range(len(hdpot_5)-1)]
VEddpot_5 = np.diff(VEdpot_5)/np.diff(hdpot_5)
plt.figure(figsize=(10,6))
plt.plot(hddpot_5,VEddpot_5,label=r'$M_t=170.849$')
plt.plot(inflec,0,'.',color='red',label=r"$V'=0$")
plt.xlabel(r'Field Value (in units of $M_p$)', fontsize=14)
plt.ylabel(r'$\displaystyle \frac{d^2V_E}{dh^2}$ (in units of $M_p^2$)', fontsize=14)
plt.legend()
plt.axis([0, 0.6, -1.5e-07, 3.5e-07])
plt.grid()
plt.show()

# %% [markdown]
# #### - Conclusion
# * At $\,M_t = 170.849GeV$, there is an inflection point such that $\,V'=V''=0$.
# * Inflection point is $\,h=0.35119$.
